# %% [markdown]
# ### Import libraries

# %%
import torch


import numpy as np
import polars as pl
import pandas as pd
from sklearn.base import clone, BaseEstimator, RegressorMixin
from copy import deepcopy
import optuna
from scipy.optimize import minimize
import os
import matplotlib.pyplot as plt
import seaborn as sns

import re
from colorama import Fore, Style

from tqdm import tqdm
from IPython.display import clear_output
from concurrent.futures import ThreadPoolExecutor

import warnings

warnings.filterwarnings("ignore")
pd.options.display.max_columns = None

import lightgbm as lgb
from catboost import CatBoostRegressor, CatBoostClassifier
from xgboost import XGBRegressor
from sklearn.ensemble import (
    VotingRegressor,
    StackingRegressor,
    GradientBoostingRegressor,
)
from sklearn.model_selection import *
from sklearn.metrics import *
from sklearn.impute import SimpleImputer, KNNImputer
from sklearn.linear_model import Ridge, LinearRegression

SEED = 42
n_splits = 5

# %% [markdown]
# ### Process file and time series

# %%
# %%time

def process_file(filename, dirname):
    df = pd.read_parquet(os.path.join(dirname, filename, 'part-0.parquet'))
    df.drop('step', axis=1, inplace=True)
    return df.describe().values.reshape(-1), filename.split('=')[1]

def load_time_series(dirname) -> pd.DataFrame:
    ids = os.listdir(dirname)
    
    with ThreadPoolExecutor() as executor:
        results = list(tqdm(executor.map(lambda fname: process_file(fname, dirname), ids), total=len(ids)))
    
    stats, indexes = zip(*results)
    
    df = pd.DataFrame(stats, columns=[f"Stat_{i}" for i in range(len(stats[0]))])
    df['id'] = indexes
    
    return df
# Out:
# CPU times: user 7 µs, sys: 0 ns, total: 7 µs
# Wall time: 11.2 µs

# %%
train = pd.read_csv(
    "/kaggle/input/child-mind-institute-problematic-internet-use/train.csv"
)
test = pd.read_csv(
    "/kaggle/input/child-mind-institute-problematic-internet-use/test.csv"
)
sample = pd.read_csv(
    "/kaggle/input/child-mind-institute-problematic-internet-use/sample_submission.csv"
)

# %%
train_ts = load_time_series(
    "/kaggle/input/child-mind-institute-problematic-internet-use/series_train.parquet"
)
test_ts = load_time_series(
    "/kaggle/input/child-mind-institute-problematic-internet-use/series_test.parquet"
)
time_series_cols = train_ts.columns.tolist()
time_series_cols.remove("id")
# Out:
# 100%|██████████| 996/996 [01:16<00:00, 12.96it/s]
# 100%|██████████| 2/2 [00:00<00:00, 10.23it/s]

# %%
train = pd.merge(train, train_ts, how="left", on="id")
test = pd.merge(test, test_ts, how="left", on="id")

train = train.drop("id", axis=1)
test = test.drop("id", axis=1)

# %%
numerical_columns = train.select_dtypes(include=["int64", "float64"]).columns.tolist()

# %%
featuresCols = [
    "Basic_Demos-Enroll_Season",
    "Basic_Demos-Age",
    "Basic_Demos-Sex",
    "CGAS-Season",
    "CGAS-CGAS_Score",
    "Physical-Season",
    "Physical-BMI",
    "Physical-Height",
    "Physical-Weight",
    "Physical-Waist_Circumference",
    "Physical-Diastolic_BP",
    "Physical-HeartRate",
    "Physical-Systolic_BP",
    "Fitness_Endurance-Season",
    "Fitness_Endurance-Max_Stage",
    "Fitness_Endurance-Time_Mins",
    "Fitness_Endurance-Time_Sec",
    "FGC-Season",
    "FGC-FGC_CU",
    "FGC-FGC_CU_Zone",
    "FGC-FGC_GSND",
    "FGC-FGC_GSND_Zone",
    "FGC-FGC_GSD",
    "FGC-FGC_GSD_Zone",
    "FGC-FGC_PU",
    "FGC-FGC_PU_Zone",
    "FGC-FGC_SRL",
    "FGC-FGC_SRL_Zone",
    "FGC-FGC_SRR",
    "FGC-FGC_SRR_Zone",
    "FGC-FGC_TL",
    "FGC-FGC_TL_Zone",
    "BIA-Season",
    "BIA-BIA_Activity_Level_num",
    "BIA-BIA_BMC",
    "BIA-BIA_BMI",
    "BIA-BIA_BMR",
    "BIA-BIA_DEE",
    "BIA-BIA_ECW",
    "BIA-BIA_FFM",
    "BIA-BIA_FFMI",
    "BIA-BIA_FMI",
    "BIA-BIA_Fat",
    "BIA-BIA_Frame_num",
    "BIA-BIA_ICW",
    "BIA-BIA_LDM",
    "BIA-BIA_LST",
    "BIA-BIA_SMM",
    "BIA-BIA_TBW",
    "PAQ_A-Season",
    "PAQ_A-PAQ_A_Total",
    "PAQ_C-Season",
    "PAQ_C-PAQ_C_Total",
    "SDS-Season",
    "SDS-SDS_Total_Raw",
    "SDS-SDS_Total_T",
    "PreInt_EduHx-Season",
    "PreInt_EduHx-computerinternet_hoursday",
    "sii",
]

featuresCols += time_series_cols

train = train[featuresCols]
train = train.dropna(subset="sii")

# %%
cat_c = [
    "Basic_Demos-Enroll_Season",
    "CGAS-Season",
    "Physical-Season",
    "Fitness_Endurance-Season",
    "FGC-Season",
    "BIA-Season",
    "PAQ_A-Season",
    "PAQ_C-Season",
    "SDS-Season",
    "PreInt_EduHx-Season",
]


def update(df):
    for c in cat_c:
        df[c] = df[c].fillna("Missing")
        df[c] = df[c].astype("category")
    return df


train = update(train)
test = update(test)


def create_mapping(column, dataset):
    unique_values = dataset[column].unique()
    return {value: idx for idx, value in enumerate(unique_values)}


for col in cat_c:
    mapping_train = create_mapping(col, train)
    mapping_test = create_mapping(col, test)

    train[col] = train[col].replace(mapping_train).astype(int)
    test[col] = test[col].replace(mapping_train).astype(int)

print(f"Train Shape : {train.shape} || Test Shape : {test.shape}")
# Out:
# Train Shape : (2736, 155) || Test Shape : (20, 154)

# %%
data = train.copy()

# %%
data
# Out:
#       Basic_Demos-Enroll_Season  Basic_Demos-Age  Basic_Demos-Sex  \
# 0                             0                5                0
# 1                             1                9                0
# 2                             1               10                1
# 3                             2                9                0
# 5                             3               13                1
# ...                         ...              ...              ...
# 3953                          0                8                0
# 3954                          1                7                1
# 3955                          0               13                0
# 3957                          0               11                0
# 3958                          3               13                0
#
#       CGAS-Season  CGAS-CGAS_Score  Physical-Season  Physical-BMI  \
# 0               0             51.0                0     16.877316
# 1               1              NaN                0     14.035590
# 2               2             71.0                0     16.648696
# 3               2             71.0                1     18.292347
# 5               0             50.0                1     22.279952
# ...           ...              ...              ...           ...
# 3953            1              NaN                0     17.139810
# 3954            1              NaN                1     13.927006
# 3955            4             60.0                0     16.362460
# 3957            4             68.0                3     21.441500
# 3958            4             70.0                3     12.235895
#
#       Physical-Height  Physical-Weight  Physical-Waist_Circumference  \
# 0                46.0             50.8                           NaN
# 1                48.0             46.0                          22.0
# 2                56.5             75.6                           NaN
# 3                56.0             81.6                           NaN
# 5                59.5            112.2                           NaN
# ...               ...              ...                           ...
# 3953             52.5             67.2                          25.0
# 3954             48.5             46.6                          23.0
# 3955             59.5             82.4                           NaN
# 3957             60.0            109.8                           NaN
# 3958             70.7             87.0                           NaN
#
#       Physical-Diastolic_BP  Physical-HeartRate  Physical-Systolic_BP  \
# 0                       NaN                 NaN                   NaN
# 1                      75.0                70.0                 122.0
# 2                      65.0                94.0                 117.0
# 3                      60.0                97.0                 117.0
# 5                      60.0                73.0                 102.0
# ...                     ...                 ...                   ...
# 3953                   60.0                65.0                 112.0
# 3954                   65.0                75.0                 105.0
# 3955                   71.0                70.0                 104.0
# 3957                   79.0                99.0                 116.0
# 3958                   59.0                61.0                 113.0
#
#       Fitness_Endurance-Season  Fitness_Endurance-Max_Stage  \
# 0                            0                          NaN
# 1                            0                          NaN
# 2                            1                          5.0
# 3                            2                          6.0
# 5                            0                          NaN
# ...                        ...                          ...
# 3953                         0                          NaN
# 3954                         0                          NaN
# 3955                         0                          NaN
# 3957                         0                          NaN
# 3958                         0                          NaN
#
#       Fitness_Endurance-Time_Mins  Fitness_Endurance-Time_Sec  FGC-Season  \
# 0                             NaN                         NaN           0
# 1                             NaN                         NaN           0
# 2                             7.0                        33.0           0
# 3                             9.0                        37.0           1
# 5                             NaN                         NaN           1
# ...                           ...                         ...         ...
# 3953                          NaN                         NaN           0
# 3954                          NaN                         NaN           1
# 3955                          NaN                         NaN           0
# 3957                          NaN                         NaN           2
# 3958                          NaN                         NaN           3
#
#       FGC-FGC_CU  FGC-FGC_CU_Zone  FGC-FGC_GSND  FGC-FGC_GSND_Zone  \
# 0            0.0              0.0           NaN                NaN
# 1            3.0              0.0           NaN                NaN
# 2           20.0              1.0          10.2                1.0
# 3           18.0              1.0           NaN                NaN
# 5           12.0              0.0          16.5                2.0
# ...          ...              ...           ...                ...
# 3953         0.0              0.0           NaN                NaN
# 3954         0.0              0.0           NaN                NaN
# 3955        16.0              0.0          18.0                1.0
# 3957        15.0              1.0          18.5                2.0
# 3958         NaN              NaN           NaN                NaN
#
#       FGC-FGC_GSD  FGC-FGC_GSD_Zone  FGC-FGC_PU  FGC-FGC_PU_Zone  FGC-FGC_SRL  \
# 0             NaN               NaN         0.0              0.0          7.0
# 1             NaN               NaN         5.0              0.0         11.0
# 2            14.7               2.0         7.0              1.0         10.0
# 3             NaN               NaN         5.0              0.0          7.0
# 5            17.9               2.0         6.0              0.0         10.0
# ...           ...               ...         ...              ...          ...
# 3953          NaN               NaN         0.0              0.0          8.0
# 3954          NaN               NaN         0.0              0.0          9.0
# 3955         19.9               2.0        10.0              1.0          8.0
# 3957         15.8               2.0         0.0              0.0         10.0
# 3958          NaN               NaN         NaN              NaN          NaN
#
#       FGC-FGC_SRL_Zone  FGC-FGC_SRR  FGC-FGC_SRR_Zone  FGC-FGC_TL  \
# 0                  0.0          6.0               0.0         6.0
# 1                  1.0         11.0               1.0         3.0
# 2                  1.0         10.0               1.0         5.0
# 3                  0.0          7.0               0.0         7.0
# 5                  1.0         11.0               1.0         8.0
# ...                ...          ...               ...         ...
# 3953               1.0         10.0               1.0        12.0
# 3954               0.0          8.5               0.0         4.5
# 3955               1.0          9.0               1.0        12.0
# 3957               1.0         10.0               1.0        14.0
# 3958               NaN          NaN               NaN         NaN
#
#       FGC-FGC_TL_Zone  BIA-Season  BIA-BIA_Activity_Level_num  BIA-BIA_BMC  \
# 0                 1.0           0                         2.0      2.66855
# 1                 0.0           1                         2.0      2.57949
# 2                 0.0           2                         NaN          NaN
# 3                 1.0           3                         3.0      3.84191
# 5                 0.0           3                         2.0      4.33036
# ...               ...         ...                         ...          ...
# 3953              1.0           0                         3.0      3.20303
# 3954              0.0           0                         1.0      2.36680
# 3955              1.0           0                         3.0      4.52277
# 3957              1.0           1                         2.0      4.41305
# 3958              NaN           3                         4.0      6.66168
#
#       BIA-BIA_BMI  BIA-BIA_BMR  BIA-BIA_DEE  BIA-BIA_ECW  BIA-BIA_FFM  \
# 0         16.8792      932.498      1492.00      8.25598      41.5862
# 1         14.0371      936.656      1498.65      6.01993      42.0291
# 2             NaN          NaN          NaN          NaN          NaN
# 3         18.2943     1131.430      1923.44     15.59250      62.7757
# 5         30.1865     1330.970      1996.45     30.21240      84.0285
# ...           ...          ...          ...          ...          ...
# 3953      17.1417     1035.270      1759.96     11.00630      52.5331
# 3954      13.6457      966.287      1256.17      9.98802      45.1853
# 3955      16.3642     1206.880      2051.70     19.46110      70.8117
# 3957      21.4438     1253.740      2005.99     20.48250      75.8033
# 3958      12.2372     1414.340      2970.12     26.53230      92.9092
#
#       BIA-BIA_FFMI  BIA-BIA_FMI  BIA-BIA_Fat  BIA-BIA_Frame_num  BIA-BIA_ICW  \
# 0          13.8177     3.061430      9.21377                1.0      24.4349
# 1          12.8254     1.211720      3.97085                1.0      21.0352
# 2              NaN          NaN          NaN                NaN          NaN
# 3          14.0740     4.220330     18.82430                2.0      30.4041
# 5          16.6877    13.498800     67.97150                2.0      32.9141
# ...            ...          ...          ...                ...          ...
# 3953       13.4004     3.741300     14.66690                1.0      25.7118
# 3954       13.2315     0.414263      1.41470                1.0      20.0572
# 3955       14.0629     2.301380     11.58830                1.0      33.3709
# 3957       14.8043     6.639520     33.99670                2.0      33.9805
# 3958       13.0684    -0.831170     -5.90917                2.0      41.3715
#
#       BIA-BIA_LDM  BIA-BIA_LST  BIA-BIA_SMM  BIA-BIA_TBW  PAQ_A-Season  \
# 0         8.89536      38.9177      19.5413      32.6909             0
# 1        14.97400      39.4497      15.4107      27.0552             0
# 2             NaN          NaN          NaN          NaN             0
# 3        16.77900      58.9338      26.4798      45.9966             0
# 5        20.90200      79.6982      35.3804      63.1265             0
# ...           ...          ...          ...          ...           ...
# 3953     15.81500      49.3301      20.2645      36.7181             0
# 3954     15.14000      42.8185      18.0937      30.0453             0
# 3955     17.97970      66.2889      29.7790      52.8320             0
# 3957     21.34030      71.3903      28.7792      54.4630             0
# 3958     25.00540      86.2475      45.4340      67.9038             0
#
#       PAQ_A-PAQ_A_Total  PAQ_C-Season  PAQ_C-PAQ_C_Total  SDS-Season  \
# 0                   NaN             0                NaN           0
# 1                   NaN             1              2.340           1
# 2                   NaN             2              2.170           1
# 3                   NaN             3              2.451           2
# 5                   NaN             4              4.110           2
# ...                 ...           ...                ...         ...
# 3953                NaN             1              3.440           1
# 3954                NaN             0                NaN           2
# 3955                NaN             3              3.260           3
# 3957                NaN             3              2.729           3
# 3958                NaN             4              3.300           4
#
#       SDS-SDS_Total_Raw  SDS-SDS_Total_T  PreInt_EduHx-Season  \
# 0                   NaN              NaN                    0
# 1                  46.0             64.0                    1
# 2                  38.0             54.0                    1
# 3                  31.0             45.0                    2
# 5                  40.0             56.0                    3
# ...                 ...              ...                  ...
# 3953               41.0             58.0                    0
# 3954               48.0             67.0                    1
# 3955               35.0             50.0                    0
# 3957               56.0             77.0                    0
# 3958               33.0             47.0                    3
#
#       PreInt_EduHx-computerinternet_hoursday  sii    Stat_0    Stat_1  \
# 0                                        3.0  2.0       NaN       NaN
# 1                                        0.0  0.0       NaN       NaN
# 2                                        2.0  0.0       NaN       NaN
# 3                                        0.0  1.0   43330.0   43330.0
# 5                                        0.0  1.0  396396.0  396396.0
# ...                                      ...  ...       ...       ...
# 3953                                     2.0  0.0       NaN       NaN
# 3954                                     0.0  1.0       NaN       NaN
# 3955                                     1.0  1.0       NaN       NaN
# 3957                                     0.0  1.0  416275.0  416275.0
# 3958                                     1.0  0.0  399000.0  399000.0
#
#         Stat_2    Stat_3    Stat_4    Stat_5    Stat_6    Stat_7    Stat_8  \
# 0          NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1          NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2          NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 3      43330.0   43330.0   43330.0   43330.0   43330.0   43330.0   43330.0
# 5     396396.0  396396.0  396396.0  396396.0  396396.0  396396.0  396396.0
# ...        ...       ...       ...       ...       ...       ...       ...
# 3953       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 3954       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 3955       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 3957  416275.0  416275.0  416275.0  416275.0  416275.0  416275.0  416275.0
# 3958  399000.0  399000.0  399000.0  399000.0  399000.0  399000.0  399000.0
#
#         Stat_9   Stat_10   Stat_11   Stat_12   Stat_13   Stat_14   Stat_15  \
# 0          NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1          NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2          NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 3      43330.0   43330.0   43330.0 -0.316384  0.016009 -0.167890  0.047388
# 5     396396.0  396396.0  396396.0 -0.004272  0.016859 -0.631731  0.011926
# ...        ...       ...       ...       ...       ...       ...       ...
# 3953       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 3954       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 3955       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 3957  416275.0  416275.0  416275.0  0.377523 -0.136917 -0.190545  0.028601
# 3958  399000.0  399000.0  399000.0  0.044563  0.080560  0.339411  0.017076
#
#         Stat_16   Stat_17    Stat_18      Stat_19       Stat_20   Stat_21  \
# 0           NaN       NaN        NaN          NaN           NaN       NaN
# 1           NaN       NaN        NaN          NaN           NaN       NaN
# 2           NaN       NaN        NaN          NaN           NaN       NaN
# 3    -10.580416  0.000000  42.296310  4053.579102  5.046215e+13  4.470182
# 5    -55.630768  0.655708  16.771982  3838.189453  4.321212e+13  3.909848
# ...         ...       ...        ...          ...           ...       ...
# 3953        NaN       NaN        NaN          NaN           NaN       NaN
# 3954        NaN       NaN        NaN          NaN           NaN       NaN
# 3955        NaN       NaN        NaN          NaN           NaN       NaN
# 3957 -12.374899  0.020323  22.480034  3844.479248  4.328291e+13  3.968833
# 3958  27.160025  0.592331   7.501198  3851.028809  4.321721e+13  3.824000
#
#       Stat_22     Stat_23   Stat_24   Stat_25   Stat_26   Stat_27    Stat_28  \
# 0         NaN         NaN       NaN       NaN       NaN       NaN        NaN
# 1         NaN         NaN       NaN       NaN       NaN       NaN        NaN
# 2         NaN         NaN       NaN       NaN       NaN       NaN        NaN
# 3         3.0   53.201683  0.453665  0.502702  0.585710  0.106351  42.947170
# 5         3.0   79.435593  0.351545  0.303812  0.623476  0.024331  50.303635
# ...       ...         ...       ...       ...       ...       ...        ...
# 3953      NaN         NaN       NaN       NaN       NaN       NaN        NaN
# 3954      NaN         NaN       NaN       NaN       NaN       NaN        NaN
# 3955      NaN         NaN       NaN       NaN       NaN       NaN        NaN
# 3957      1.0   60.263729  0.523033  0.422859  0.538802  0.072386  38.895920
# 3958      1.0  312.557983  0.321881  0.346819  0.807518  0.065688  67.432198
#
#        Stat_29     Stat_30     Stat_31       Stat_32   Stat_33  Stat_34  \
# 0          NaN         NaN         NaN           NaN       NaN      NaN
# 1          NaN         NaN         NaN           NaN       NaN      NaN
# 2          NaN         NaN         NaN           NaN       NaN      NaN
# 3     0.000000  208.168976  112.404045  1.942842e+13  1.931421      0.0
# 5     0.468723   95.327438  155.573868  2.497264e+13  1.946892      0.0
# ...        ...         ...         ...           ...       ...      ...
# 3953       NaN         NaN         NaN           NaN       NaN      NaN
# 3954       NaN         NaN         NaN           NaN       NaN      NaN
# 3955       NaN         NaN         NaN           NaN       NaN      NaN
# 3957  0.139045  110.340538  167.268799  2.493436e+13  1.899374      0.0
# 3958  0.481510   14.348840  165.152405  2.489514e+13  1.999010      0.0
#
#         Stat_35   Stat_36   Stat_37   Stat_38  Stat_39    Stat_40  Stat_41  \
# 0           NaN       NaN       NaN       NaN      NaN        NaN      NaN
# 1           NaN       NaN       NaN       NaN      NaN        NaN      NaN
# 2           NaN       NaN       NaN       NaN      NaN        NaN      NaN
# 3     14.244914 -1.746094 -2.905339 -1.048372      0.0 -89.833092      0.0
# 5      6.634319 -1.038711 -1.522690 -1.018787      0.0 -88.761833      0.0
# ...         ...       ...       ...       ...      ...        ...      ...
# 3953        NaN       NaN       NaN       NaN      NaN        NaN      NaN
# 3954        NaN       NaN       NaN       NaN      NaN        NaN      NaN
# 3955        NaN       NaN       NaN       NaN      NaN        NaN      NaN
# 3957   6.960978 -1.852794 -0.992487 -1.006157      0.0 -89.627525      0.0
# 3958   6.677634 -1.708816 -2.080256 -1.010877      0.0 -89.846863      0.0
#
#       Stat_42      Stat_43       Stat_44  Stat_45  Stat_46  Stat_47   Stat_48  \
# 0         NaN          NaN           NaN      NaN      NaN      NaN       NaN
# 1         NaN          NaN           NaN      NaN      NaN      NaN       NaN
# 2         NaN          NaN           NaN      NaN      NaN      NaN       NaN
# 3         0.0  3824.000000  5.500000e+10      1.0      3.0     41.0 -0.684180
# 5         0.0  3098.166748  0.000000e+00      1.0      3.0     68.0 -0.052803
# ...       ...          ...           ...      ...      ...      ...       ...
# 3953      NaN          NaN           NaN      NaN      NaN      NaN       NaN
# 3954      NaN          NaN           NaN      NaN      NaN      NaN       NaN
# 3955      NaN          NaN           NaN      NaN      NaN      NaN       NaN
# 3957      0.0  3098.166748  0.000000e+00      1.0      1.0     48.0  0.015931
# 3958      0.0  3098.166748  0.000000e+00      1.0      1.0    301.0 -0.016745
#
#        Stat_49   Stat_50   Stat_51    Stat_52  Stat_53   Stat_54      Stat_55  \
# 0          NaN       NaN       NaN        NaN      NaN       NaN          NaN
# 1          NaN       NaN       NaN        NaN      NaN       NaN          NaN
# 2          NaN       NaN       NaN        NaN      NaN       NaN          NaN
# 3    -0.309863 -0.649974  0.006432 -41.541863      0.0  2.392969  4028.666748
# 5    -0.044517 -1.009344  0.008622 -88.386049      0.0  0.500000  3747.000000
# ...        ...       ...       ...        ...      ...       ...          ...
# 3953       NaN       NaN       NaN        NaN      NaN       NaN          NaN
# 3954       NaN       NaN       NaN        NaN      NaN       NaN          NaN
# 3955       NaN       NaN       NaN        NaN      NaN       NaN          NaN
# 3957 -0.431110 -0.616714  0.000683 -39.189468      0.0  1.958715  3741.000000
# 3958 -0.016340 -0.373187  0.000558 -22.638031      0.0  2.135821  3747.000000
#
#            Stat_56  Stat_57  Stat_58  Stat_59   Stat_60   Stat_61   Stat_62  \
# 0              NaN      NaN      NaN      NaN       NaN       NaN       NaN
# 1              NaN      NaN      NaN      NaN       NaN       NaN       NaN
# 2              NaN      NaN      NaN      NaN       NaN       NaN       NaN
# 3     3.689000e+13      3.0      3.0     42.0 -0.366849  0.024974 -0.245378
# 5     2.154000e+13      2.0      3.0     74.0 -0.020622 -0.028179 -1.007728
# ...            ...      ...      ...      ...       ...       ...       ...
# 3953           NaN      NaN      NaN      NaN       NaN       NaN       NaN
# 3954           NaN      NaN      NaN      NaN       NaN       NaN       NaN
# 3955           NaN      NaN      NaN      NaN       NaN       NaN       NaN
# 3957  2.168000e+13      2.0      1.0     54.0  0.538555 -0.153108 -0.277119
# 3958  2.168000e+13      2.0      1.0    307.0  0.028056  0.009200  0.855105
#
#        Stat_63    Stat_64  Stat_65   Stat_66  Stat_67       Stat_68  Stat_69  \
# 0          NaN        NaN      NaN       NaN      NaN           NaN      NaN
# 1          NaN        NaN      NaN       NaN      NaN           NaN      NaN
# 2          NaN        NaN      NaN       NaN      NaN           NaN      NaN
# 3     0.023637 -15.086617      0.0  6.926828   4070.0  5.347750e+13      5.0
# 5     0.009831 -86.119919      1.0  0.879005   3812.0  4.331000e+13      4.0
# ...        ...        ...      ...       ...      ...           ...      ...
# 3953       NaN        NaN      NaN       NaN      NaN           NaN      NaN
# 3954       NaN        NaN      NaN       NaN      NaN           NaN      NaN
# 3955       NaN        NaN      NaN       NaN      NaN           NaN      NaN
# 3957  0.008805 -16.722418      0.0  5.282995   3812.0  4.336000e+13      4.0
# 3958  0.009563  57.570095      1.0  4.523121   3818.0  4.336500e+13      4.0
#
#       Stat_70  Stat_71   Stat_72   Stat_73   Stat_74   Stat_75    Stat_76  \
# 0         NaN      NaN       NaN       NaN       NaN       NaN        NaN
# 1         NaN      NaN       NaN       NaN       NaN       NaN        NaN
# 2         NaN      NaN       NaN       NaN       NaN       NaN        NaN
# 3         3.0     50.0 -0.010677  0.400677  0.204727  0.041420  12.220764
# 5         3.0     79.0 -0.019081  0.020307 -0.294459  0.010668 -17.483364
# ...       ...      ...       ...       ...       ...       ...        ...
# 3953      NaN      NaN       NaN       NaN       NaN       NaN        NaN
# 3954      NaN      NaN       NaN       NaN       NaN       NaN        NaN
# 3955      NaN      NaN       NaN       NaN       NaN       NaN        NaN
# 3957      1.0     60.0  0.813215  0.086647  0.148035  0.025942   8.457803
# 3958      1.0    313.0  0.069484  0.076909  1.008843  0.014023  87.467171
#
#       Stat_77    Stat_78      Stat_79       Stat_80  Stat_81  Stat_82  \
# 0         NaN        NaN          NaN           NaN      NaN      NaN
# 1         NaN        NaN          NaN           NaN      NaN      NaN
# 2         NaN        NaN          NaN           NaN      NaN      NaN
# 3         0.0  15.000000  4147.000000  6.640875e+13      6.0      3.0
# 5         1.0   6.141348  3951.187561  6.485500e+13      6.0      3.0
# ...       ...        ...          ...           ...      ...      ...
# 3953      NaN        NaN          NaN           NaN      NaN      NaN
# 3954      NaN        NaN          NaN           NaN      NaN      NaN
# 3955      NaN        NaN          NaN           NaN      NaN      NaN
# 3957      0.0  13.859835  3964.000000  6.492500e+13      5.0      1.0
# 3958      1.0   7.471756  3970.000000  6.471500e+13      6.0      1.0
#
#       Stat_83   Stat_84   Stat_85   Stat_86   Stat_87    Stat_88  Stat_89  \
# 0         NaN       NaN       NaN       NaN       NaN        NaN      NaN
# 1         NaN       NaN       NaN       NaN       NaN        NaN      NaN
# 2         NaN       NaN       NaN       NaN       NaN        NaN      NaN
# 3        53.0  1.507865  1.666354  1.546979  4.004276  89.751656      0.0
# 5        85.0  1.034351  1.946303  1.146284  2.952888  89.476036      1.0
# ...       ...       ...       ...       ...       ...        ...      ...
# 3953      NaN       NaN       NaN       NaN       NaN        NaN      NaN
# 3954      NaN       NaN       NaN       NaN       NaN        NaN      NaN
# 3955      NaN       NaN       NaN       NaN       NaN        NaN      NaN
# 3957     66.0  1.622884  2.286455  1.468296  3.078876  89.693832      1.0
# 3958    318.0  1.755602  2.166893  1.467054  3.417329  89.931534      1.0
#
#           Stat_90  Stat_91       Stat_92  Stat_93  Stat_94  Stat_95
# 0             NaN      NaN           NaN      NaN      NaN      NaN
# 1             NaN      NaN           NaN      NaN      NaN      NaN
# 2             NaN      NaN           NaN      NaN      NaN      NaN
# 3     2633.250000   4188.5  8.611000e+13      7.0      3.0     85.0
# 5     2597.800049   4175.0  8.639500e+13      7.0      3.0     91.0
# ...           ...      ...           ...      ...      ...      ...
# 3953          NaN      NaN           NaN      NaN      NaN      NaN
# 3954          NaN      NaN           NaN      NaN      NaN      NaN
# 3955          NaN      NaN           NaN      NaN      NaN      NaN
# 3957  2605.750000   4185.0  8.639500e+13      7.0      1.0     72.0
# 3958  1186.599976   4189.0  8.639500e+13      7.0      1.0    324.0
#
# [2736 rows x 155 columns]

# %% [markdown]
# #### Calculate correlation

# %%
selected_features = [
    "Basic_Demos-Age",
    "Basic_Demos-Sex",
    "CGAS-CGAS_Score",
    "Physical-BMI",
    "Physical-Height",
    "Physical-Weight",
    "Physical-Waist_Circumference",
    "Physical-Diastolic_BP",
    "Physical-HeartRate",
    "Physical-Systolic_BP",
    "Fitness_Endurance-Max_Stage",
    "Fitness_Endurance-Time_Mins",
    "Fitness_Endurance-Time_Sec",
    "FGC-FGC_CU",
    "FGC-FGC_CU_Zone",
    "FGC-FGC_GSND",
    "FGC-FGC_GSND_Zone",
    "FGC-FGC_GSD",
    "FGC-FGC_GSD_Zone",
    "FGC-FGC_PU",
    "FGC-FGC_PU_Zone",
    "FGC-FGC_SRL",
    "FGC-FGC_SRL_Zone",
    "FGC-FGC_SRR",
    "FGC-FGC_SRR_Zone",
    "FGC-FGC_TL",
    "FGC-FGC_TL_Zone",
    "BIA-BIA_Activity_Level_num",
    "BIA-BIA_BMC",
    "BIA-BIA_BMI",
    "BIA-BIA_BMR",
    "BIA-BIA_DEE",
    "BIA-BIA_ECW",
    "BIA-BIA_FFM",
    "BIA-BIA_FFMI",
    "BIA-BIA_FMI",
    "BIA-BIA_Fat",
    "BIA-BIA_Frame_num",
    "BIA-BIA_ICW",
    "BIA-BIA_LDM",
    "BIA-BIA_LST",
    "BIA-BIA_SMM",
    "BIA-BIA_TBW",
    "PAQ_A-PAQ_A_Total",
    "PAQ_C-PAQ_C_Total",
    "SDS-SDS_Total_Raw",
    "SDS-SDS_Total_T",
    "PreInt_EduHx-computerinternet_hoursday",
    "sii",
]

correlation_matrix = train[selected_features].corr()

# %%
top_corr = correlation_matrix["sii"].sort_values(ascending=False)
print(top_corr)
# Out:
# sii                                       1.000000
# Physical-Height                           0.373530
# Basic_Demos-Age                           0.365990
# PreInt_EduHx-computerinternet_hoursday    0.336526
# Physical-Weight                           0.325938
# Physical-Waist_Circumference              0.272885
# FGC-FGC_CU                                0.247364
# SDS-SDS_Total_T                           0.232982
# SDS-SDS_Total_Raw                         0.229692
# BIA-BIA_BMI                               0.227818
# Physical-BMI                              0.221125
# FGC-FGC_PU                                0.177125
# BIA-BIA_Frame_num                         0.165936
# FGC-FGC_GSD                               0.163448
# FGC-FGC_GSND                              0.149495
# Physical-Systolic_BP                      0.135336
# FGC-FGC_TL                                0.107623
# BIA-BIA_FFMI                              0.102702
# BIA-BIA_FMI                               0.077054
# BIA-BIA_LST                               0.067603
# BIA-BIA_Activity_Level_num                0.060085
# Physical-Diastolic_BP                     0.050971
# FGC-FGC_PU_Zone                           0.048652
# BIA-BIA_SMM                               0.046692
# BIA-BIA_ICW                               0.046653
# BIA-BIA_DEE                               0.045239
# BIA-BIA_TBW                               0.037513
# BIA-BIA_Fat                               0.037357
# BIA-BIA_BMR                               0.031965
# BIA-BIA_FFM                               0.031965
# BIA-BIA_ECW                               0.030414
# FGC-FGC_GSD_Zone                          0.023696
# BIA-BIA_LDM                               0.021696
# Fitness_Endurance-Time_Sec                0.008701
# PAQ_C-PAQ_C_Total                         0.005665
# FGC-FGC_GSND_Zone                         0.001667
# BIA-BIA_BMC                              -0.010336
# FGC-FGC_CU_Zone                          -0.023944
# Physical-HeartRate                       -0.024572
# FGC-FGC_TL_Zone                          -0.026753
# FGC-FGC_SRR                              -0.035858
# FGC-FGC_SRL                              -0.049257
# PAQ_A-PAQ_A_Total                        -0.050386
# Fitness_Endurance-Time_Mins              -0.060628
# FGC-FGC_SRR_Zone                         -0.068528
# Fitness_Endurance-Max_Stage              -0.070589
# CGAS-CGAS_Score                          -0.085261
# Basic_Demos-Sex                          -0.100148
# FGC-FGC_SRL_Zone                         -0.112497
# Name: sii, dtype: float64

# %%
selected_features = correlation_matrix[correlation_matrix["sii"] > 0.1].index.tolist()
print("Selected Features for Modeling:", selected_features)
# Out:
# Selected Features for Modeling: ['Basic_Demos-Age', 'Physical-BMI', 'Physical-Height', 'Physical-Weight', 'Physical-Waist_Circumference', 'Physical-Systolic_BP', 'FGC-FGC_CU', 'FGC-FGC_GSND', 'FGC-FGC_GSD', 'FGC-FGC_PU', 'FGC-FGC_TL', 'BIA-BIA_BMI', 'BIA-BIA_FFMI', 'BIA-BIA_Frame_num', 'SDS-SDS_Total_Raw', 'SDS-SDS_Total_T', 'PreInt_EduHx-computerinternet_hoursday', 'sii']

# %%
selected_features += time_series_cols

train = train[selected_features]

# %%
test_selected = [
    "Basic_Demos-Age",
    "Physical-BMI",
    "Physical-Height",
    "Physical-Weight",
    "Physical-Waist_Circumference",
    "Physical-Systolic_BP",
    "FGC-FGC_CU",
    "FGC-FGC_GSND",
    "FGC-FGC_GSD",
    "FGC-FGC_PU",
    "FGC-FGC_TL",
    "BIA-BIA_BMI",
    "BIA-BIA_FFMI",
    "BIA-BIA_Frame_num",
    "SDS-SDS_Total_Raw",
    "SDS-SDS_Total_T",
    "PreInt_EduHx-computerinternet_hoursday",
]
test_selected += time_series_cols
test = test[test_selected]

# %%
# %%time

def quadratic_weighted_kappa(y_true, y_pred):
    return cohen_kappa_score(y_true, y_pred, weights='quadratic')

def threshold_Rounder(oof_non_rounded, thresholds):
    return np.where(oof_non_rounded < thresholds[0], 0,
                    np.where(oof_non_rounded < thresholds[1], 1,
                             np.where(oof_non_rounded < thresholds[2], 2, 3)))

def evaluate_predictions(thresholds, y_true, oof_non_rounded):
    rounded_p = threshold_Rounder(oof_non_rounded, thresholds)
    return -quadratic_weighted_kappa(y_true, rounded_p)

def TrainML(model_class, test_data):
    
    X = train.drop(['sii'], axis=1)
    y = train['sii']

    SKF = RepeatedStratifiedKFold(n_splits=n_splits, n_repeats=1, random_state=SEED)
    
    train_S = []
    test_S = []
    
    oof_non_rounded = np.zeros(len(y), dtype=float) 
    oof_rounded = np.zeros(len(y), dtype=int) 
    test_preds = np.zeros((len(test_data), n_splits))

    for fold, (train_idx, test_idx) in enumerate(tqdm(SKF.split(X, y), desc="Training Folds", total=n_splits)):
        X_train, X_val = X.iloc[train_idx], X.iloc[test_idx]
        y_train, y_val = y.iloc[train_idx], y.iloc[test_idx]

        model = clone(model_class)
        model.fit(X_train, y_train)

        y_train_pred = model.predict(X_train)
        y_val_pred = model.predict(X_val)

        oof_non_rounded[test_idx] = y_val_pred
        y_val_pred_rounded = y_val_pred.round(0).astype(int)
        oof_rounded[test_idx] = y_val_pred_rounded

        train_kappa = quadratic_weighted_kappa(y_train, y_train_pred.round(0).astype(int))
        val_kappa = quadratic_weighted_kappa(y_val, y_val_pred_rounded)

        train_S.append(train_kappa)
        test_S.append(val_kappa)
        
        test_preds[:, fold] = model.predict(test_data)
        
        print(f"Fold {fold+1} - Train QWK: {train_kappa:.4f}, Validation QWK: {val_kappa:.4f}")
        clear_output(wait=True)

    print(f"Mean Train QWK --> {np.mean(train_S):.4f}")
    print(f"Mean Validation QWK ---> {np.mean(test_S):.4f}")

    KappaOPtimizer = minimize(evaluate_predictions,
                              x0=[0.5, 1.5, 2.5], args=(y, oof_non_rounded), 
                              method='Nelder-Mead') # Nelder-Mead | # Powell
    assert KappaOPtimizer.success, "Optimization did not converge."
    
    oof_tuned = threshold_Rounder(oof_non_rounded, KappaOPtimizer.x)
    tKappa = quadratic_weighted_kappa(y, oof_tuned)

    print(f"----> || Optimized QWK SCORE :: {Fore.CYAN}{Style.BRIGHT} {tKappa:.3f}{Style.RESET_ALL}")

    tpm = test_preds.mean(axis=1)
    tpTuned = threshold_Rounder(tpm, KappaOPtimizer.x)
    
    submission = pd.DataFrame({
        'id': sample['id'],
        'sii': tpTuned
    })

    return submission,model
# Out:
# CPU times: user 6 µs, sys: 0 ns, total: 6 µs
# Wall time: 10.5 µs

# %%
# params3 = {'lambda_l1': 2.9209409268664883,
#  'lambda_l2': 0.00012976118112242174,
#  'num_leaves': 202,
#  'feature_fraction': 0.8038056112369449,
#  'bagging_fraction': 0.6991108077097957,
#  'bagging_freq': 3,
#  "learning_rate": 0.05,
#  'min_child_samples': 85}
catboost_params = {
    "learning_rate": 0.019252771685694288,
    "depth": 7,
    "subsample": 0.40628186539007644,
    "colsample_bylevel": 0.6904206855559013,
    "min_data_in_leaf": 38,
}
# XGB_Params = {'lambda_l1': 0.1543921843752799,
#  'lambda_l2': 0.000281461450194636,
#  'num_leaves': 2,
#  'feature_fraction': 0.6799895242815174,
#  'bagging_fraction': 0.5050148144157642,
#  'bagging_freq': 1,
#  'min_child_samples': 86}

# %%
cat = CatBoostRegressor(**catboost_params)

# %%
Submission, model = TrainML(cat, test)
# Out:
# Training Folds: 100%|██████████| 5/5 [02:35<00:00, 31.12s/it]
# Mean Train QWK --> 0.7233
# Mean Validation QWK ---> 0.3715
# ----> || Optimized QWK SCORE ::  0.454

# %%
# %%time

Submission.to_csv('submission.csv', index=False)
print(Submission['sii'].value_counts())
# Out:
# sii
# 0    11
# 1     9
# Name: count, dtype: int64
# CPU times: user 8.95 ms, sys: 1.99 ms, total: 10.9 ms
# Wall time: 13.5 ms
